# %%
import pyspark
import pandas as pd
import numpy as np
spark = pyspark.sql.SparkSession.builder.getOrCreate()
from pyspark.sql.functions import *
from pyspark.sql.functions import lit
from pyspark.sql.functions import regexp_extract, regexp_replace

# %% [markdown]
# #### Remember: you have to 'register' a table to query it with spark.sql
# - mpg.createOrReplaceTempView("mpg")

# %%
pandas_df = pd.read_csv('activities.csv')

# %%
pandas_df.head()
# Out:
#    Activity ID              Activity Date     Activity Name Activity Type  \
# 0    350128633   Jul 20, 2015, 1:06:57 PM  Renecca creek rd          Ride
# 1    623600149  Oct 11, 2015, 10:03:14 PM    Afternoon Ride          Ride
# 2    797001969    Dec 8, 2016, 4:28:12 PM      Morning Ride          Ride
# 3    800888948  Dec 12, 2016, 10:22:44 PM    Afternoon Ride          Ride
# 4    811340614  Dec 25, 2016, 10:37:32 PM    Afternoon Ride          Ride
#
#   Activity Description  Elapsed Time  Distance  Max Heart Rate  \
# 0                  NaN          2352     13.48             NaN
# 1                  NaN          5495     23.61             NaN
# 2                  NaN             8      0.03             NaN
# 3                  NaN          7942     10.22           149.0
# 4                  NaN          4983     26.16           162.0
#
#    Relative Effort  Commute  ...  UV Index Weather Ozone  \
# 0              NaN    False  ...       NaN           NaN
# 1              NaN    False  ...       NaN           NaN
# 2              NaN    False  ...       NaN           NaN
# 3              8.0    False  ...       NaN           NaN
# 4             32.0    False  ...       NaN           NaN
#
#    <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.jump_count">Jump Count</span>  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.total_grit">Total Grit</span>  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.avg_flow">Avg Flow</span>  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.flagged">Flagged</span>  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.avg_elapsed_speed">Avg Elapsed Speed</span>  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.dirt_distance">Dirt Distance</span>  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.newly_explored_distance">Newly Explored Distance</span>  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.newly_explored_dirt_distance">Newly Explored Dirt Distance</span>
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 83 columns]

# %%
pandas_df['Activity Type'].value_counts()
# Out:
# Ride    346
# Run     165
# Hike     10
# Name: Activity Type, dtype: int64

# %%
pandas_df.columns.to_list()
# Out:
# ['Activity ID',
#  'Activity Date',
#  'Activity Name',
#  'Activity Type',
#  'Activity Description',
#  'Elapsed Time',
#  'Distance',
#  'Max Heart Rate',
#  'Relative Effort',
#  'Commute',
#  'Activity Gear',
#  'Filename',
#  'Athlete Weight',
#  'Bike Weight',
#  'Elapsed Time.1',
#  'Moving Time',
#  'Distance.1',
#  'Max Speed',
#  'Average Speed',
#  'Elevation Gain',
#  'Elevation Loss',
#  'Elevation Low',
#  'Elevation High',
#  'Max Grade',
#  'Average Grade',
#  'Average Positive Grade',
#  'Average Negative Grade',
#  'Max Cadence',
#  'Average Cadence',
#  'Max Heart Rate.1',
#  'Average Heart Rate',
#  'Max Watts',
#  'Average Watts',
#  'Calories',
#  'Max Temperature',
#  'Average Temperature',
#  'Relative Effort.1',
#  'Total Work',
#  'Number of Runs',
#  'Uphill Time',
#  'Downhill Time',
#  'Other Time',
#  'Perceived Exertion',
#  '<span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.type">Type</span>',
#  '<span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.start_time">Start Time</span>',
#  'Weighted Average Power',
#  'Power Count',
#  'Prefer Perceived Exertion',
#  'Perceived Relative Effort',
#  'Commute.1',
#  'Total Weight Lifted',
#  'From Upload',
#  'Grade Adjusted Distance',
#  'Weather Observation Time',
#  'Weather Condition',
#  'Weather Temperature',
#  'Apparent Temperature',
#  'Dewpoint',
#  'Humidity',
#  'Weather Pressure',
#  'Wind Speed',
#  'Wind Gust',
#  'Wind Bearing',
#  'Precipitation Intensity',
#  'Sunrise Time',
#  'Sunset Time',
#  'Moon Phase',
#  'Bike',
#  'Gear',
#  'Precipitation Probability',
#  'Precipitation Type',
#  'Cloud Cover',
#  'Weather Visibility',
#  'UV Index',
#  'Weather Ozone',
#  '<span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.jump_count">Jump Count</span>',
#  '<span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.total_grit">Total Grit</span>',
#  '<span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.avg_flow">Avg Flow</span>',
#  '<span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.flagged">Flagged</span>',
#  '<span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.avg_elapsed_speed">Avg Elapsed Speed</span>',
#  '<span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.dirt_distance">Dirt Distance</span>',
#  '<span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.newly_explored_distance">Newly Explored Distance</span>',
#  '<span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.newly_explored_dirt_distance">Newly Explored Dirt Distance</span>']

# %%
cols = ['Activity ID',
 'Activity Date',
 'Activity Name',
 'Activity Type',
 'Elapsed Time',
 'Distance',
 'Elapsed Time.1',
 'Moving Time',
 'Distance.1',
 'Max Speed',
 'Average Speed',
 'Elevation Gain',
 'Elevation Loss',
 'Elevation Low',
 'Elevation High',
 'Max Grade',
 'Average Grade',
 'Average Watts',
 'Calories']

# %%
pandas_df[cols].isna().sum()
# Out:
# Activity ID         0
# Activity Date       0
# Activity Name       0
# Activity Type       0
# Elapsed Time        0
# Distance            0
# Elapsed Time.1      5
# Moving Time         0
# Distance.1          0
# Max Speed           0
# Average Speed     148
# Elevation Gain      4
# Elevation Loss    155
# Elevation Low       0
# Elevation High      0
# Max Grade           0
# Average Grade       0
# Average Watts     176
# Calories           38
# dtype: int64

# %%
activities = pandas_df[cols]

# %%
activities = activities.rename(columns={'Activity ID':'Activity_ID',
 'Activity Date': 'Activity_date',
 'Activity Name': 'Activity_name',
 'Activity Type': 'Activity_Type',
 'Elapsed Time': 'Elapsed_Time_Secs',
 'Elapsed Time.1':'Elapsed_Time_1',
 'Distance': 'Distance_KM',
 'Moving Time': 'Moving_Time_Secs',
 'Distance.1': 'Distance_1',
 'Max Speed':'Max_Speed',
 'Average Speed':'Average_Speed',
 'Elevation Gain': 'Elevation_Gain',
 'Elevation Loss':'Elevation_Loss',
 'Elevation Low':'Elevation_Low',
 'Elevation High':'Elevation_High',
 'Max Grade':'Max_Grade',
 'Average Grade':'Average_Grade',
 'Average Watts':'Average_Watts'})

# %%
activities.head().T
# Out:
#                                           0                          1  \
# Activity_ID                       350128633                  623600149
# Activity_date      Jul 20, 2015, 1:06:57 PM  Oct 11, 2015, 10:03:14 PM
# Activity_name              Renecca creek rd             Afternoon Ride
# Activity_Type                          Ride                       Ride
# Elapsed_Time_Secs                      2352                       5495
# Distance_KM                           13.48                      23.61
# Elapsed_Time_1                       2352.0                     5495.0
# Moving_Time_Secs                     2272.0                     3965.0
# Distance_1                     13482.599609               23613.199219
# Max_Speed                              16.0                       15.1
# Average_Speed                           NaN                        NaN
# Elevation_Gain                   187.078995                 213.251999
# Elevation_Loss                          NaN                        NaN
# Elevation_Low                    283.799988                 283.799988
# Elevation_High                   406.899994                      407.5
# Max_Grade                         16.799999                       19.9
# Average_Grade                      0.726863                        0.0
# Average_Watts                           NaN                 150.570999
# Calories                                NaN                        NaN
#
#                                          2                          3  \
# Activity_ID                      797001969                  800888948
# Activity_date      Dec 8, 2016, 4:28:12 PM  Dec 12, 2016, 10:22:44 PM
# Activity_name                 Morning Ride             Afternoon Ride
# Activity_Type                         Ride                       Ride
# Elapsed_Time_Secs                        8                       7942
# Distance_KM                           0.03                      10.22
# Elapsed_Time_1                         8.0                     7942.0
# Moving_Time_Secs                       8.0                     1851.0
# Distance_1                            30.6               10228.599609
# Max_Speed                              0.2                       14.5
# Average_Speed                          NaN                        NaN
# Elevation_Gain                         0.0                  47.843739
# Elevation_Loss                         NaN                        NaN
# Elevation_Low                   207.899994                      208.0
# Elevation_High                  207.899994                 235.699997
# Max_Grade                              0.0                  23.799999
# Average_Grade                          0.0                  -0.004888
# Average_Watts                          0.0                 115.796242
# Calories                               NaN                 238.987305
#
#                                            4
# Activity_ID                        811340614
# Activity_date      Dec 25, 2016, 10:37:32 PM
# Activity_name                 Afternoon Ride
# Activity_Type                           Ride
# Elapsed_Time_Secs                       4983
# Distance_KM                            26.16
# Elapsed_Time_1                        4983.0
# Moving_Time_Secs                      4424.0
# Distance_1                      26168.800781
# Max_Speed                               15.1
# Average_Speed                            NaN
# Elevation_Gain                     73.213295
# Elevation_Loss                           NaN
# Elevation_Low                          194.0
# Elevation_High                    244.600006
# Max_Grade                               22.4
# Average_Grade                      -0.009171
# Average_Watts                     121.938919
# Calories                                 NaN

# %%
activities.to_csv('activities2.csv')

# %%
# df = spark.createDataFrame(pandas_df)


# the usual method is throwing errors related to data types
# some columns have multiple dtypes (NaN, values, etc); giving pyspark issues

# %%
df = (spark.read.format("csv").options(header="true")
    .load("activities2.csv"))

# %%
df.show(5, vertical=True)
# Out:
# -RECORD 0---------------------------------
#  _c0               | 0
#  Activity_ID       | 350128633
#  Activity_date     | Jul 20, 2015, 1:0...
#  Activity_name     | Renecca creek rd
#  Activity_Type     | Ride
#  Elapsed_Time_Secs | 2352
#  Distance_KM       | 13.48
#  Elapsed_Time_1    | 2352.0
#  Moving_Time_Secs  | 2272.0
#  Distance_1        | 13482.599609375
#  Max_Speed         | 16.0
#  Average_Speed     | null
#  Elevation_Gain    | 187.07899475097656
#  Elevation_Loss    | null
#  Elevation_Low     | 283.79998779296875
#  Elevation_High    | 406.8999938964844
#  Max_Grade         | 16.799999237060547
#  Average_Grade     | 0.7268630266189575
#  Average_Watts     | null
#  Calories          | null
# -RECORD 1---------------------------------
#  _c0               | 1
#  Activity_ID       | 623600149
#  Activity_date     | Oct 11, 2015, 10:...
#  Activity_name     | Afternoon Ride
#  Activity_Type     | Ride
#  Elapsed_Time_Secs | 5495
#  Distance_KM       | 23.61
#  Elapsed_Time_1    | 5495.0
#  Moving_Time_Secs  | 3965.0
#  Distance_1        | 23613.19921875
#  Max_Speed         | 15.100000381469728
#  Average_Speed     | null
#  Elevation_Gain    | 213.2519989013672
#  Elevation_Loss    | null
#  Elevation_Low     | 283.79998779296875
#  Elevation_High    | 407.5
#  Max_Grade         | 19.899999618530277
#  Average_Grade     | 0.0
#  Average_Watts     | 150.5709991455078
#  Calories          | null
# -RECORD 2---------------------------------
#  _c0               | 2
#  Activity_ID       | 797001969
#  Activity_date     | Dec 8, 2016, 4:28...
#  Activity_name     | Morning Ride
#  Activity_Type     | Ride
#  Elapsed_Time_Secs | 8
#  Distance_KM       | 0.03
#  Elapsed_Time_1    | 8.0
#  Moving_Time_Secs  | 8.0
#  Distance_1        | 30.600000381469727
#  Max_Speed         | 0.2000000029802322
#  Average_Speed     | null
#  Elevation_Gain    | 0.0
#  Elevation_Loss    | null
#  Elevation_Low     | 207.8999938964844
#  Elevation_High    | 207.8999938964844
#  Max_Grade         | 0.0
#  Average_Grade     | 0.0
#  Average_Watts     | 0.0
#  Calories          | null
# -RECORD 3---------------------------------
#  _c0               | 3
#  Activity_ID       | 800888948
#  Activity_date     | Dec 12, 2016, 10:...
#  Activity_name     | Afternoon Ride
#  Activity_Type     | Ride
#  Elapsed_Time_Secs | 7942
#  Distance_KM       | 10.22
#  Elapsed_Time_1    | 7942.0
#  Moving_Time_Secs  | 1851.0
#  Distance_1        | 10228.599609375
#  Max_Speed         | 14.5
#  Average_Speed     | null
#  Elevation_Gain    | 47.8437385559082
#  Elevation_Loss    | null
#  Elevation_Low     | 208.0
#  Elevation_High    | 235.6999969482422
#  Max_Grade         | 23.799999237060547
#  Average_Grade     | -0.0048882546834647
#  Average_Watts     | 115.7962417602539
#  Calories          | 238.9873046875
# -RECORD 4---------------------------------
#  _c0               | 4
#  Activity_ID       | 811340614
#  Activity_date     | Dec 25, 2016, 10:...
#  Activity_name     | Afternoon Ride
#  Activity_Type     | Ride
#  Elapsed_Time_Secs | 4983
#  Distance_KM       | 26.16
#  Elapsed_Time_1    | 4983.0
#  Moving_Time_Secs  | 4424.0
#  Distance_1        | 26168.80078125
#  Max_Speed         | 15.100000381469728
#  Average_Speed     | null
#  Elevation_Gain    | 73.21329498291016
#  Elevation_Loss    | null
#  Elevation_Low     | 194.0
#  Elevation_High    | 244.6000061035156
#  Max_Grade         | 22.399999618530277
#  Average_Grade     | -0.0091712269932031
#  Average_Watts     | 121.9389190673828
#  Calories          | null
# only showing top 5 rows

# %%
print('DataFrame shape', df.count(), ' x ', len(df.columns))
# Out:
# DataFrame shape 521  x  20

# %%
# df.describe().show(vertical = True)

# %%
df.createOrReplaceTempView("df")

# %%
spark.sql(
    """
SELECT Distance_KM, Elapsed_Time_Secs, Distance_KM/(Moving_Time_Secs / 3600) AS Avg_Speed_km_hr
FROM df
"""
).show(5)
# Out:
# +-----------+-----------------+------------------+
# |Distance_KM|Elapsed_Time_Secs|   Avg_Speed_km_hr|
# +-----------+-----------------+------------------+
# |      13.48|             2352|21.359154929577468|
# |      23.61|             5495|21.436569987389657|
# |       0.03|                8|              13.5|
# |      10.22|             7942| 19.87682333873582|
# |      26.16|             4983|  21.2875226039783|
# +-----------+-----------------+------------------+
# only showing top 5 rows

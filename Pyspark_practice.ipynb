# %%
import pyspark
import pandas as pd
import numpy as np
spark = pyspark.sql.SparkSession.builder.getOrCreate()
from pyspark.sql.functions import *
from pyspark.sql.functions import lit
from pyspark.sql.functions import regexp_extract, regexp_replace
import re

# %% [markdown]
# #### Remember: you have to 'register' a table to query it with spark.sql
# - mpg.createOrReplaceTempView("mpg")

# %%
pandas_df = pd.read_csv('activities.csv')

# %%
pandas_df.head()
# Out:
#    Activity ID              Activity Date     Activity Name Activity Type  \
# 0    350128633   Jul 20, 2015, 1:06:57 PM  Renecca creek rd          Ride
# 1    623600149  Oct 11, 2015, 10:03:14 PM    Afternoon Ride          Ride
# 2    797001969    Dec 8, 2016, 4:28:12 PM      Morning Ride          Ride
# 3    800888948  Dec 12, 2016, 10:22:44 PM    Afternoon Ride          Ride
# 4    811340614  Dec 25, 2016, 10:37:32 PM    Afternoon Ride          Ride
#
#   Activity Description  Elapsed Time  Distance  Max Heart Rate  \
# 0                  NaN          2352     13.48             NaN
# 1                  NaN          5495     23.61             NaN
# 2                  NaN             8      0.03             NaN
# 3                  NaN          7942     10.22           149.0
# 4                  NaN          4983     26.16           162.0
#
#    Relative Effort  Commute  ...  UV Index Weather Ozone  \
# 0              NaN    False  ...       NaN           NaN
# 1              NaN    False  ...       NaN           NaN
# 2              NaN    False  ...       NaN           NaN
# 3              8.0    False  ...       NaN           NaN
# 4             32.0    False  ...       NaN           NaN
#
#    <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.jump_count">Jump Count</span>  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.total_grit">Total Grit</span>  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.avg_flow">Avg Flow</span>  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.flagged">Flagged</span>  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.avg_elapsed_speed">Avg Elapsed Speed</span>  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.dirt_distance">Dirt Distance</span>  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.newly_explored_distance">Newly Explored Distance</span>  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.newly_explored_dirt_distance">Newly Explored Dirt Distance</span>
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 83 columns]

# %%
pandas_df['Activity Type'].value_counts()
# Out:
# Ride    346
# Run     165
# Hike     10
# Name: Activity Type, dtype: int64

# %%
pandas_df.columns.to_list()
# Out:
# ['Activity ID',
#  'Activity Date',
#  'Activity Name',
#  'Activity Type',
#  'Activity Description',
#  'Elapsed Time',
#  'Distance',
#  'Max Heart Rate',
#  'Relative Effort',
#  'Commute',
#  'Activity Gear',
#  'Filename',
#  'Athlete Weight',
#  'Bike Weight',
#  'Elapsed Time.1',
#  'Moving Time',
#  'Distance.1',
#  'Max Speed',
#  'Average Speed',
#  'Elevation Gain',
#  'Elevation Loss',
#  'Elevation Low',
#  'Elevation High',
#  'Max Grade',
#  'Average Grade',
#  'Average Positive Grade',
#  'Average Negative Grade',
#  'Max Cadence',
#  'Average Cadence',
#  'Max Heart Rate.1',
#  'Average Heart Rate',
#  'Max Watts',
#  'Average Watts',
#  'Calories',
#  'Max Temperature',
#  'Average Temperature',
#  'Relative Effort.1',
#  'Total Work',
#  'Number of Runs',
#  'Uphill Time',
#  'Downhill Time',
#  'Other Time',
#  'Perceived Exertion',
#  '<span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.type">Type</span>',
#  '<span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.start_time">Start Time</span>',
#  'Weighted Average Power',
#  'Power Count',
#  'Prefer Perceived Exertion',
#  'Perceived Relative Effort',
#  'Commute.1',
#  'Total Weight Lifted',
#  'From Upload',
#  'Grade Adjusted Distance',
#  'Weather Observation Time',
#  'Weather Condition',
#  'Weather Temperature',
#  'Apparent Temperature',
#  'Dewpoint',
#  'Humidity',
#  'Weather Pressure',
#  'Wind Speed',
#  'Wind Gust',
#  'Wind Bearing',
#  'Precipitation Intensity',
#  'Sunrise Time',
#  'Sunset Time',
#  'Moon Phase',
#  'Bike',
#  'Gear',
#  'Precipitation Probability',
#  'Precipitation Type',
#  'Cloud Cover',
#  'Weather Visibility',
#  'UV Index',
#  'Weather Ozone',
#  '<span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.jump_count">Jump Count</span>',
#  '<span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.total_grit">Total Grit</span>',
#  '<span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.avg_flow">Avg Flow</span>',
#  '<span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.flagged">Flagged</span>',
#  '<span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.avg_elapsed_speed">Avg Elapsed Speed</span>',
#  '<span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.dirt_distance">Dirt Distance</span>',
#  '<span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.newly_explored_distance">Newly Explored Distance</span>',
#  '<span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.newly_explored_dirt_distance">Newly Explored Dirt Distance</span>']

# %%
cols = ['Activity ID',
 'Activity Date',
 'Activity Name',
 'Activity Type',
 'Elapsed Time',
 'Distance',
 'Elapsed Time.1',
 'Moving Time',
 'Distance.1',
 'Max Speed',
 'Average Speed',
 'Elevation Gain',
 'Elevation Loss',
 'Elevation Low',
 'Elevation High',
 'Max Grade',
 'Average Grade',
 'Average Watts',
 'Calories']

# %%
pandas_df[cols].isna().sum()
# Out:
# Activity ID         0
# Activity Date       0
# Activity Name       0
# Activity Type       0
# Elapsed Time        0
# Distance            0
# Elapsed Time.1      5
# Moving Time         0
# Distance.1          0
# Max Speed           0
# Average Speed     148
# Elevation Gain      4
# Elevation Loss    155
# Elevation Low       0
# Elevation High      0
# Max Grade           0
# Average Grade       0
# Average Watts     176
# Calories           38
# dtype: int64

# %%
activities = pandas_df[cols]

# %%
activities = activities.rename(columns={'Activity ID':'Activity_ID',
 'Activity Date': 'Activity_date',
 'Activity Name': 'Activity_name',
 'Activity Type': 'Activity_Type',
 'Elapsed Time': 'Elapsed_Time_Secs',
 'Elapsed Time.1':'Elapsed_Time_1',
 'Distance': 'Distance_KM',
 'Moving Time': 'Moving_Time_Secs',
 'Distance.1': 'Distance_1',
 'Max Speed':'Max_Speed',
 'Average Speed':'Average_Speed',
 'Elevation Gain': 'Elevation_Gain',
 'Elevation Loss':'Elevation_Loss',
 'Elevation Low':'Elevation_Low',
 'Elevation High':'Elevation_High',
 'Max Grade':'Max_Grade',
 'Average Grade':'Average_Grade',
 'Average Watts':'Average_Watts'})

# %%
activities.head().T
# Out:
#                                           0                          1  \
# Activity_ID                       350128633                  623600149
# Activity_date      Jul 20, 2015, 1:06:57 PM  Oct 11, 2015, 10:03:14 PM
# Activity_name              Renecca creek rd             Afternoon Ride
# Activity_Type                          Ride                       Ride
# Elapsed_Time_Secs                      2352                       5495
# Distance_KM                           13.48                      23.61
# Elapsed_Time_1                       2352.0                     5495.0
# Moving_Time_Secs                     2272.0                     3965.0
# Distance_1                     13482.599609               23613.199219
# Max_Speed                              16.0                       15.1
# Average_Speed                           NaN                        NaN
# Elevation_Gain                   187.078995                 213.251999
# Elevation_Loss                          NaN                        NaN
# Elevation_Low                    283.799988                 283.799988
# Elevation_High                   406.899994                      407.5
# Max_Grade                         16.799999                       19.9
# Average_Grade                      0.726863                        0.0
# Average_Watts                           NaN                 150.570999
# Calories                                NaN                        NaN
#
#                                          2                          3  \
# Activity_ID                      797001969                  800888948
# Activity_date      Dec 8, 2016, 4:28:12 PM  Dec 12, 2016, 10:22:44 PM
# Activity_name                 Morning Ride             Afternoon Ride
# Activity_Type                         Ride                       Ride
# Elapsed_Time_Secs                        8                       7942
# Distance_KM                           0.03                      10.22
# Elapsed_Time_1                         8.0                     7942.0
# Moving_Time_Secs                       8.0                     1851.0
# Distance_1                            30.6               10228.599609
# Max_Speed                              0.2                       14.5
# Average_Speed                          NaN                        NaN
# Elevation_Gain                         0.0                  47.843739
# Elevation_Loss                         NaN                        NaN
# Elevation_Low                   207.899994                      208.0
# Elevation_High                  207.899994                 235.699997
# Max_Grade                              0.0                  23.799999
# Average_Grade                          0.0                  -0.004888
# Average_Watts                          0.0                 115.796242
# Calories                               NaN                 238.987305
#
#                                            4
# Activity_ID                        811340614
# Activity_date      Dec 25, 2016, 10:37:32 PM
# Activity_name                 Afternoon Ride
# Activity_Type                           Ride
# Elapsed_Time_Secs                       4983
# Distance_KM                            26.16
# Elapsed_Time_1                        4983.0
# Moving_Time_Secs                      4424.0
# Distance_1                      26168.800781
# Max_Speed                               15.1
# Average_Speed                            NaN
# Elevation_Gain                     73.213295
# Elevation_Loss                           NaN
# Elevation_Low                          194.0
# Elevation_High                    244.600006
# Max_Grade                               22.4
# Average_Grade                      -0.009171
# Average_Watts                     121.938919
# Calories                                 NaN

# %%
activities.to_csv('activities2.csv')

# %%
# df = spark.createDataFrame(pandas_df)


# the usual method is throwing errors related to data types
# some columns have multiple dtypes (NaN, values, etc); giving pyspark issues

# %%
df = (spark.read.format("csv").options(header="true")
    .load("activities2.csv"))

# %%
df.show(5, vertical=True)
# Out:
# -RECORD 0---------------------------------
#  _c0               | 0
#  Activity_ID       | 350128633
#  Activity_date     | Jul 20, 2015, 1:0...
#  Activity_name     | Renecca creek rd
#  Activity_Type     | Ride
#  Elapsed_Time_Secs | 2352
#  Distance_KM       | 13.48
#  Elapsed_Time_1    | 2352.0
#  Moving_Time_Secs  | 2272.0
#  Distance_1        | 13482.599609375
#  Max_Speed         | 16.0
#  Average_Speed     | null
#  Elevation_Gain    | 187.07899475097656
#  Elevation_Loss    | null
#  Elevation_Low     | 283.79998779296875
#  Elevation_High    | 406.8999938964844
#  Max_Grade         | 16.799999237060547
#  Average_Grade     | 0.7268630266189575
#  Average_Watts     | null
#  Calories          | null
# -RECORD 1---------------------------------
#  _c0               | 1
#  Activity_ID       | 623600149
#  Activity_date     | Oct 11, 2015, 10:...
#  Activity_name     | Afternoon Ride
#  Activity_Type     | Ride
#  Elapsed_Time_Secs | 5495
#  Distance_KM       | 23.61
#  Elapsed_Time_1    | 5495.0
#  Moving_Time_Secs  | 3965.0
#  Distance_1        | 23613.19921875
#  Max_Speed         | 15.100000381469728
#  Average_Speed     | null
#  Elevation_Gain    | 213.2519989013672
#  Elevation_Loss    | null
#  Elevation_Low     | 283.79998779296875
#  Elevation_High    | 407.5
#  Max_Grade         | 19.899999618530277
#  Average_Grade     | 0.0
#  Average_Watts     | 150.5709991455078
#  Calories          | null
# -RECORD 2---------------------------------
#  _c0               | 2
#  Activity_ID       | 797001969
#  Activity_date     | Dec 8, 2016, 4:28...
#  Activity_name     | Morning Ride
#  Activity_Type     | Ride
#  Elapsed_Time_Secs | 8
#  Distance_KM       | 0.03
#  Elapsed_Time_1    | 8.0
#  Moving_Time_Secs  | 8.0
#  Distance_1        | 30.600000381469727
#  Max_Speed         | 0.2000000029802322
#  Average_Speed     | null
#  Elevation_Gain    | 0.0
#  Elevation_Loss    | null
#  Elevation_Low     | 207.8999938964844
#  Elevation_High    | 207.8999938964844
#  Max_Grade         | 0.0
#  Average_Grade     | 0.0
#  Average_Watts     | 0.0
#  Calories          | null
# -RECORD 3---------------------------------
#  _c0               | 3
#  Activity_ID       | 800888948
#  Activity_date     | Dec 12, 2016, 10:...
#  Activity_name     | Afternoon Ride
#  Activity_Type     | Ride
#  Elapsed_Time_Secs | 7942
#  Distance_KM       | 10.22
#  Elapsed_Time_1    | 7942.0
#  Moving_Time_Secs  | 1851.0
#  Distance_1        | 10228.599609375
#  Max_Speed         | 14.5
#  Average_Speed     | null
#  Elevation_Gain    | 47.8437385559082
#  Elevation_Loss    | null
#  Elevation_Low     | 208.0
#  Elevation_High    | 235.6999969482422
#  Max_Grade         | 23.799999237060547
#  Average_Grade     | -0.0048882546834647
#  Average_Watts     | 115.7962417602539
#  Calories          | 238.9873046875
# -RECORD 4---------------------------------
#  _c0               | 4
#  Activity_ID       | 811340614
#  Activity_date     | Dec 25, 2016, 10:...
#  Activity_name     | Afternoon Ride
#  Activity_Type     | Ride
#  Elapsed_Time_Secs | 4983
#  Distance_KM       | 26.16
#  Elapsed_Time_1    | 4983.0
#  Moving_Time_Secs  | 4424.0
#  Distance_1        | 26168.80078125
#  Max_Speed         | 15.100000381469728
#  Average_Speed     | null
#  Elevation_Gain    | 73.21329498291016
#  Elevation_Loss    | null
#  Elevation_Low     | 194.0
#  Elevation_High    | 244.6000061035156
#  Max_Grade         | 22.399999618530277
#  Average_Grade     | -0.0091712269932031
#  Average_Watts     | 121.9389190673828
#  Calories          | null
# only showing top 5 rows

# %%
print('DataFrame shape', df.count(), ' x ', len(df.columns))
# Out:
# DataFrame shape 521  x  20

# %%
# df.describe().show(vertical = True)

# %% [markdown]
# ## Note the registration of the df for spark.sql use

# %%
df.createOrReplaceTempView("df")

# %%
spark.sql(
    """
SELECT Distance_KM, Elapsed_Time_Secs, Distance_KM/(Moving_Time_Secs / 3600) AS Avg_Speed_km_hr
FROM df
"""
).show(5)
# Out:
# +-----------+-----------------+------------------+
# |Distance_KM|Elapsed_Time_Secs|   Avg_Speed_km_hr|
# +-----------+-----------------+------------------+
# |      13.48|             2352|21.359154929577468|
# |      23.61|             5495|21.436569987389657|
# |       0.03|                8|              13.5|
# |      10.22|             7942| 19.87682333873582|
# |      26.16|             4983|  21.2875226039783|
# +-----------+-----------------+------------------+
# only showing top 5 rows

# %% [markdown]
# - Strava has some null values in the avrage speepd attribute, which it shouldn't, so I will go back and add as a feature using pyspark

# %%
df.columns
# Out:
# ['_c0',
#  'Activity_ID',
#  'Activity_date',
#  'Activity_name',
#  'Activity_Type',
#  'Elapsed_Time_Secs',
#  'Distance_KM',
#  'Elapsed_Time_1',
#  'Moving_Time_Secs',
#  'Distance_1',
#  'Max_Speed',
#  'Average_Speed',
#  'Elevation_Gain',
#  'Elevation_Loss',
#  'Elevation_Low',
#  'Elevation_High',
#  'Max_Grade',
#  'Average_Grade',
#  'Average_Watts',
#  'Calories']

# %%
df.select(concat(df.Activity_Type,lit(' '), df.Activity_date)).show(5)
# Out:
# +---------------------------------------+
# |concat(Activity_Type,  , Activity_date)|
# +---------------------------------------+
# |                   Ride Jul 20, 2015...|
# |                   Ride Oct 11, 2015...|
# |                   Ride Dec 8, 2016,...|
# |                   Ride Dec 12, 2016...|
# |                   Ride Dec 25, 2016...|
# +---------------------------------------+
# only showing top 5 rows

# %%
df.select(df.Activity_date).show(5, truncate = False)
# Out:
# +-------------------------+
# |Activity_date            |
# +-------------------------+
# |Jul 20, 2015, 1:06:57 PM |
# |Oct 11, 2015, 10:03:14 PM|
# |Dec 8, 2016, 4:28:12 PM  |
# |Dec 12, 2016, 10:22:44 PM|
# |Dec 25, 2016, 10:37:32 PM|
# +-------------------------+
# only showing top 5 rows

# %%
regexp_extract(col('Notes'), '(.)(by)(\s+)(\w+)', 4))
'.by\s+(\w+)', 1
r"^(\w{3})(\s)(,)(\d{4})",1
# Out:
#   File "<ipython-input-23-c3b54f6466ff>", line 1
#     regexp_extract(col('Notes'), '(.)(by)(\s+)(\w+)', 4))
#                                                         ^
# SyntaxError: unmatched ')'

# %%
df.select(
    "Activity_Type",
    regexp_extract("Activity_Date", r"^(\w{3})", 1).alias("Month"),
    regexp_extract("Activity_Date", r"^\w{3}\s\d{1,2}(,)\s(.{4})",2).alias("Year"),
).show(5,truncate=False)

# %% [markdown]
# - ok, you got the year.  why is it group 2 though? regex.

# %%
# the answer to my question on stackoverflow : )


from pyspark.sql import functions as F

df1 = (df.withColumn("Activity_date", F.to_timestamp("Activity_date", "MMM d, yyyy, h:mm:ss a"))
       .withColumn("Month", F.date_format("Activity_date", "MMM"))
       .withColumn("Year", F.year("Activity_date"))
       )

df1.show(vertical=True)
# Out:
# -RECORD 0--------------------------------
#  _c0               | 0
#  Activity_ID       | 350128633
#  Activity_date     | 2015-07-20 13:06:57
#  Activity_name     | Renecca creek rd
#  Activity_Type     | Ride
#  Elapsed_Time_Secs | 2352
#  Distance_KM       | 13.48
#  Elapsed_Time_1    | 2352.0
#  Moving_Time_Secs  | 2272.0
#  Distance_1        | 13482.599609375
#  Max_Speed         | 16.0
#  Average_Speed     | null
#  Elevation_Gain    | 187.07899475097656
#  Elevation_Loss    | null
#  Elevation_Low     | 283.79998779296875
#  Elevation_High    | 406.8999938964844
#  Max_Grade         | 16.799999237060547
#  Average_Grade     | 0.7268630266189575
#  Average_Watts     | null
#  Calories          | null
#  Month             | Jul
#  Year              | 2015
# -RECORD 1--------------------------------
#  _c0               | 1
#  Activity_ID       | 623600149
#  Activity_date     | 2015-10-11 22:03:14
#  Activity_name     | Afternoon Ride
#  Activity_Type     | Ride
#  Elapsed_Time_Secs | 5495
#  Distance_KM       | 23.61
#  Elapsed_Time_1    | 5495.0
#  Moving_Time_Secs  | 3965.0
#  Distance_1        | 23613.19921875
#  Max_Speed         | 15.100000381469728
#  Average_Speed     | null
#  Elevation_Gain    | 213.2519989013672
#  Elevation_Loss    | null
#  Elevation_Low     | 283.79998779296875
#  Elevation_High    | 407.5
#  Max_Grade         | 19.899999618530277
#  Average_Grade     | 0.0
#  Average_Watts     | 150.5709991455078
#  Calories          | null
#  Month             | Oct
#  Year              | 2015
# -RECORD 2--------------------------------
#  _c0               | 2
#  Activity_ID       | 797001969
#  Activity_date     | 2016-12-08 16:28:12
#  Activity_name     | Morning Ride
#  Activity_Type     | Ride
#  Elapsed_Time_Secs | 8
#  Distance_KM       | 0.03
#  Elapsed_Time_1    | 8.0
#  Moving_Time_Secs  | 8.0
#  Distance_1        | 30.600000381469727
#  Max_Speed         | 0.2000000029802322
#  Average_Speed     | null
#  Elevation_Gain    | 0.0
#  Elevation_Loss    | null
#  Elevation_Low     | 207.8999938964844
#  Elevation_High    | 207.8999938964844
#  Max_Grade         | 0.0
#  Average_Grade     | 0.0
#  Average_Watts     | 0.0
#  Calories          | null
#  Month             | Dec
#  Year              | 2016
# -RECORD 3--------------------------------
#  _c0               | 3
#  Activity_ID       | 800888948
#  Activity_date     | 2016-12-12 22:22:44
#  Activity_name     | Afternoon Ride
#  Activity_Type     | Ride
#  Elapsed_Time_Secs | 7942
#  Distance_KM       | 10.22
#  Elapsed_Time_1    | 7942.0
#  Moving_Time_Secs  | 1851.0
#  Distance_1        | 10228.599609375
#  Max_Speed         | 14.5
#  Average_Speed     | null
#  Elevation_Gain    | 47.8437385559082
#  Elevation_Loss    | null
#  Elevation_Low     | 208.0
#  Elevation_High    | 235.6999969482422
#  Max_Grade         | 23.799999237060547
#  Average_Grade     | -0.0048882546834647
#  Average_Watts     | 115.7962417602539
#  Calories          | 238.9873046875
#  Month             | Dec
#  Year              | 2016
# -RECORD 4--------------------------------
#  _c0               | 4
#  Activity_ID       | 811340614
#  Activity_date     | 2016-12-25 22:37:32
#  Activity_name     | Afternoon Ride
#  Activity_Type     | Ride
#  Elapsed_Time_Secs | 4983
#  Distance_KM       | 26.16
#  Elapsed_Time_1    | 4983.0
#  Moving_Time_Secs  | 4424.0
#  Distance_1        | 26168.80078125
#  Max_Speed         | 15.100000381469728
#  Average_Speed     | null
#  Elevation_Gain    | 73.21329498291016
#  Elevation_Loss    | null
#  Elevation_Low     | 194.0
#  Elevation_High    | 244.6000061035156
#  Max_Grade         | 22.399999618530277
#  Average_Grade     | -0.0091712269932031
#  Average_Watts     | 121.9389190673828
#  Calories          | null
#  Month             | Dec
#  Year              | 2016
# -RECORD 5--------------------------------
#  _c0               | 5
#  Activity_ID       | 852175835
#  Activity_date     | 2017-02-01 20:14:13
#  Activity_name     | Afternoon Ride
#  Activity_Type     | Ride
#  Elapsed_Time_Secs | 11270
#  Distance_KM       | 12.25
#  Elapsed_Time_1    | 11270.0
#  Moving_Time_Secs  | 3562.0
#  Distance_1        | 12254.0
#  Max_Speed         | 10.899999618530272
#  Average_Speed     | null
#  Elevation_Gain    | 60.99600982666016
#  Elevation_Loss    | null
#  Elevation_Low     | 207.1000061035156
#  Elevation_High    | 234.0
#  Max_Grade         | 9.800000190734863
#  Average_Grade     | 0.0016321201110258
#  Average_Watts     | 78.58424377441406
#  Calories          | 312.1073608398437
#  Month             | Feb
#  Year              | 2017
# -RECORD 6--------------------------------
#  _c0               | 6
#  Activity_ID       | 874019573
#  Activity_date     | 2017-02-20 22:55:45
#  Activity_name     | Afternoon Ride
#  Activity_Type     | Ride
#  Elapsed_Time_Secs | 8235
#  Distance_KM       | 9.82
#  Elapsed_Time_1    | 8235.0
#  Moving_Time_Secs  | 1646.0
#  Distance_1        | 9826.2001953125
#  Max_Speed         | 12.100000381469728
#  Average_Speed     | null
#  Elevation_Gain    | 59.80400466918945
#  Elevation_Loss    | null
#  Elevation_Low     | 208.0
#  Elevation_High    | 234.0
#  Max_Grade         | 11.0
#  Average_Grade     | -0.0010176873765885
#  Average_Watts     | 125.86026000976562
#  Calories          | null
#  Month             | Feb
#  Year              | 2017
# -RECORD 7--------------------------------
#  _c0               | 7
#  Activity_ID       | 885712336
#  Activity_date     | 2017-03-03 00:28:45
#  Activity_name     | Evening Ride
#  Activity_Type     | Ride
#  Elapsed_Time_Secs | 9322
#  Distance_KM       | 37.42
#  Elapsed_Time_1    | 9322.0
#  Moving_Time_Secs  | 6375.0
#  Distance_1        | 37424.5
#  Max_Speed         | 14.399999618530272
#  Average_Speed     | null
#  Elevation_Gain    | 135.79783630371094
#  Elevation_Loss    | null
#  Elevation_Low     | 190.1000061035156
#  Elevation_High    | 244.0
#  Max_Grade         | 14.199999809265137
#  Average_Grade     | -0.0716108456254005
#  Average_Watts     | 129.95303344726562
#  Calories          | null
#  Month             | Mar
#  Year              | 2017
# -RECORD 8--------------------------------
#  _c0               | 8
#  Activity_ID       | 890545741
#  Activity_date     | 2017-03-06 23:54:44
#  Activity_name     | Evening Ride
#  Activity_Type     | Ride
#  Elapsed_Time_Secs | 14725
#  Distance_KM       | 47.55
#  Elapsed_Time_1    | 14725.0
#  Moving_Time_Secs  | 7106.0
#  Distance_1        | 47554.8984375
#  Max_Speed         | 13.699999809265137
#  Average_Speed     | null
#  Elevation_Gain    | 76.22856903076172
#  Elevation_Loss    | null
#  Elevation_Low     | 156.8000030517578
#  Elevation_High    | 220.0
#  Max_Grade         | 9.699999809265137
#  Average_Grade     | -0.0016822661273181
#  Average_Watts     | 145.51560974121094
#  Calories          | null
#  Month             | Mar
#  Year              | 2017
# -RECORD 9--------------------------------
#  _c0               | 9
#  Activity_ID       | 900600691
#  Activity_date     | 2017-03-15 00:41:56
#  Activity_name     | Evening Ride
#  Activity_Type     | Ride
#  Elapsed_Time_Secs | 2365
#  Distance_KM       | 5.49
#  Elapsed_Time_1    | 2365.0
#  Moving_Time_Secs  | 1912.0
#  Distance_1        | 5491.2001953125
#  Max_Speed         | 5.0
#  Average_Speed     | null
#  Elevation_Gain    | 15.713393211364746
#  Elevation_Loss    | null
#  Elevation_Low     | 210.0
#  Elevation_High    | 226.0
#  Max_Grade         | 5.699999809265137
#  Average_Grade     | -0.0291375294327735
#  Average_Watts     | 35.89242172241211
#  Calories          | null
#  Month             | Mar
#  Year              | 2017
# -RECORD 10-------------------------------
#  _c0               | 10
#  Activity_ID       | 912020485
#  Activity_date     | 2017-03-16 00:41:27
#  Activity_name     | Evening Ride
#  Activity_Type     | Ride
#  Elapsed_Time_Secs | 1272
#  Distance_KM       | 3.69
#  Elapsed_Time_1    | 1272.0
#  Moving_Time_Secs  | 1241.0
#  Distance_1        | 3698.300048828125
#  Max_Speed         | 5.300000190734863
#  Average_Speed     | null
#  Elevation_Gain    | 0.0
#  Elevation_Loss    | null
#  Elevation_Low     | 217.1000061035156
#  Elevation_High    | 227.0
#  Max_Grade         | 5.5
#  Average_Grade     | 0.0081118354573845
#  Average_Watts     | 61.57212066650391
#  Calories          | 85.19823455810547
#  Month             | Mar
#  Year              | 2017
# -RECORD 11-------------------------------
#  _c0               | 11
#  Activity_ID       | 912020511
#  Activity_date     | 2017-03-24 00:01:14
#  Activity_name     | Evening Ride
#  Activity_Type     | Ride
#  Elapsed_Time_Secs | 6665
#  Distance_KM       | 28.42
#  Elapsed_Time_1    | 6665.0
#  Moving_Time_Secs  | 4287.0
#  Distance_1        | 28426.0
#  Max_Speed         | 17.200000762939453
#  Average_Speed     | null
#  Elevation_Gain    | 136.9837646484375
#  Elevation_Loss    | null
#  Elevation_Low     | 190.6999969482422
#  Elevation_High    | 243.8000030517578
#  Max_Grade         | 12.100000381469728
#  Average_Grade     | -0.0010553718311712
#  Average_Watts     | 118.63084411621094
#  Calories          | null
#  Month             | Mar
#  Year              | 2017
# -RECORD 12-------------------------------
#  _c0               | 12
#  Activity_ID       | 920184630
#  Activity_date     | 2017-03-26 17:24:35
#  Activity_name     | Lunch Ride
#  Activity_Type     | Ride
#  Elapsed_Time_Secs | 267771
#  Distance_KM       | 18.62
#  Elapsed_Time_1    | 267771.0
#  Moving_Time_Secs  | 5014.0
#  Distance_1        | 18619.900390625
#  Max_Speed         | 13.300000190734863
#  Average_Speed     | null
#  Elevation_Gain    | 12.966666221618652
#  Elevation_Loss    | null
#  Elevation_Low     | 183.0
#  Elevation_High    | 220.0
#  Max_Grade         | 14.600000381469728
#  Average_Grade     | -0.1353390663862228
#  Average_Watts     | 59.35134506225586
#  Calories          | 331.8099670410156
#  Month             | Mar
#  Year              | 2017
# -RECORD 13-------------------------------
#  _c0               | 13
#  Activity_ID       | 920184661
#  Activity_date     | 2017-03-29 19:47:40
#  Activity_name     | Afternoon Ride
#  Activity_Type     | Ride
#  Elapsed_Time_Secs | 17863
#  Distance_KM       | 33.63
#  Elapsed_Time_1    | 17863.0
#  Moving_Time_Secs  | 6533.0
#  Distance_1        | 33632.30078125
#  Max_Speed         | 13.199999809265137
#  Average_Speed     | null
#  Elevation_Gain    | 53.09999847412109
#  Elevation_Loss    | null
#  Elevation_Low     | 166.89999389648438
#  Elevation_High    | 220.0
#  Max_Grade         | 23.399999618530277
#  Average_Grade     | 0.0008919996325857
#  Average_Watts     | 99.70939636230467
#  Calories          | null
#  Month             | Mar
#  Year              | 2017
# -RECORD 14-------------------------------
#  _c0               | 14
#  Activity_ID       | 951123526
#  Activity_date     | 2017-04-09 20:48:26
#  Activity_name     | Afternoon Ride
#  Activity_Type     | Ride
#  Elapsed_Time_Secs | 15660
#  Distance_KM       | 16.09
#  Elapsed_Time_1    | 15660.0
#  Moving_Time_Secs  | 3022.0
#  Distance_1        | 16093.2998046875
#  Max_Speed         | 14.0
#  Average_Speed     | null
#  Elevation_Gain    | 53.83629989624024
#  Elevation_Loss    | null
#  Elevation_Low     | 194.1000061035156
#  Elevation_High    | 238.0
#  Max_Grade         | 6.5
#  Average_Grade     | -0.018019899725914
#  Average_Watts     | 92.96389770507812
#  Calories          | null
#  Month             | Apr
#  Year              | 2017
# -RECORD 15-------------------------------
#  _c0               | 15
#  Activity_ID       | 951123556
#  Activity_date     | 2017-04-20 23:16:21
#  Activity_name     | Evening Ride
#  Activity_Type     | Ride
#  Elapsed_Time_Secs | 15832
#  Distance_KM       | 48.86
#  Elapsed_Time_1    | 15832.0
#  Moving_Time_Secs  | 7063.0
#  Distance_1        | 48865.69921875
#  Max_Speed         | 13.800000190734863
#  Average_Speed     | null
#  Elevation_Gain    | 97.40670013427734
#  Elevation_Loss    | null
#  Elevation_Low     | 150.10000610351562
#  Elevation_High    | 225.0
#  Max_Grade         | 8.199999809265137
#  Average_Grade     | -0.0004092850140295
#  Average_Watts     | 136.4669952392578
#  Calories          | 1074.7110595703125
#  Month             | Apr
#  Year              | 2017
# -RECORD 16-------------------------------
#  _c0               | 16
#  Activity_ID       | 977488497
#  Activity_date     | 2017-04-30 15:12:37
#  Activity_name     | Morning Ride
#  Activity_Type     | Ride
#  Elapsed_Time_Secs | 720241
#  Distance_KM       | 16.74
#  Elapsed_Time_1    | 720241.0
#  Moving_Time_Secs  | 4886.0
#  Distance_1        | 16748.5
#  Max_Speed         | 14.899999618530272
#  Average_Speed     | null
#  Elevation_Gain    | 76.48725891113281
#  Elevation_Loss    | null
#  Elevation_Low     | 196.0
#  Elevation_High    | 236.0
#  Max_Grade         | 18.0
#  Average_Grade     | 0.0
#  Average_Watts     | 69.53939819335938
#  Calories          | null
#  Month             | Apr
#  Year              | 2017
# -RECORD 17-------------------------------
#  _c0               | 17
#  Activity_ID       | 977511652
#  Activity_date     | 2017-05-08 23:16:40
#  Activity_name     | Evening Ride
#  Activity_Type     | Ride
#  Elapsed_Time_Secs | 10302
#  Distance_KM       | 46.25
#  Elapsed_Time_1    | 10302.0
#  Moving_Time_Secs  | 6259.0
#  Distance_1        | 46253.19921875
#  Max_Speed         | 14.300000190734863
#  Average_Speed     | null
#  Elevation_Gain    | 76.18571472167969
#  Elevation_Loss    | null
#  Elevation_Low     | 156.8000030517578
#  Elevation_High    | 220.0
#  Max_Grade         | 16.700000762939453
#  Average_Grade     | 0.0002162012533517
#  Average_Watts     | 143.92604064941406
#  Calories          | null
#  Month             | May
#  Year              | 2017
# -RECORD 18-------------------------------
#  _c0               | 18
#  Activity_ID       | 990524656
#  Activity_date     | 2017-05-16 16:37:29
#  Activity_name     | Lunch Ride
#  Activity_Type     | Ride
#  Elapsed_Time_Secs | 9479
#  Distance_KM       | 6.4
#  Elapsed_Time_1    | 9479.0
#  Moving_Time_Secs  | 1292.0
#  Distance_1        | 6401.5
#  Max_Speed         | 13.0
#  Average_Speed     | null
#  Elevation_Gain    | 0.0
#  Elevation_Loss    | null
#  Elevation_Low     | 193.8000030517578
#  Elevation_High    | 220.0
#  Max_Grade         | 6.699999809265137
#  Average_Grade     | -0.3561665117740631
#  Average_Watts     | 85.16653442382812
#  Calories          | null
#  Month             | May
#  Year              | 2017
# -RECORD 19-------------------------------
#  _c0               | 19
#  Activity_ID       | 1000392426
#  Activity_date     | 2017-05-21 20:39:58
#  Activity_name     | Afternoon Run
#  Activity_Type     | Run
#  Elapsed_Time_Secs | 2185
#  Distance_KM       | 6.19
#  Elapsed_Time_1    | 2185.0
#  Moving_Time_Secs  | 1959.0
#  Distance_1        | 6197.10009765625
#  Max_Speed         | 6.199999809265137
#  Average_Speed     | null
#  Elevation_Gain    | 16.891666412353516
#  Elevation_Loss    | null
#  Elevation_Low     | 209.0
#  Elevation_High    | 226.0
#  Max_Grade         | 6.099999904632568
#  Average_Grade     | -0.0225912127643823
#  Average_Watts     | null
#  Calories          | 708.8445434570312
#  Month             | May
#  Year              | 2017
# only showing top 20 rows

# %%
example = "Jul 20, 2015, 1:06:57 PM"

# %%
re.search(r"^\w{3}", example)
# Out:
# <re.Match object; span=(0, 3), match='Jul'>

# %%
re.search(r"^\w{3}\s\d{1,2}", example)
# Out:
# <re.Match object; span=(0, 6), match='Jul 20'>

# %%
re.search(r"^\w{3}\s\d{1,2}(,)", example)
# Out:
# <re.Match object; span=(0, 7), match='Jul 20,'>

# %%
re.search(r"^\w{3}\s\d{1,2}(,)\s(.{4})", example)
# Out:
# <re.Match object; span=(0, 12), match='Jul 20, 2015'>

# %%
df.filter(df.Distance_KM > 80).show(5, vertical=True)
# Out:
# -RECORD 0---------------------------------
#  _c0               | 176
#  Activity_ID       | 3753411577
#  Activity_date     | Jul 12, 2020, 3:0...
#  Activity_name     | Morning Ride
#  Activity_Type     | Ride
#  Elapsed_Time_Secs | 16873
#  Distance_KM       | 82.52
#  Elapsed_Time_1    | 16873.0
#  Moving_Time_Secs  | 13586.0
#  Distance_1        | 82523.8984375
#  Max_Speed         | 13.600000381469728
#  Average_Speed     | 6.0741868019104
#  Elevation_Gain    | 505.89007568359375
#  Elevation_Loss    | 505.8900146484375
#  Elevation_Low     | 200.0
#  Elevation_High    | 319.20001220703125
#  Max_Grade         | 22.600000381469727
#  Average_Grade     | 0.0
#  Average_Watts     | 146.6240692138672
#  Calories          | 2221.117431640625
# -RECORD 1---------------------------------
#  _c0               | 194
#  Activity_ID       | 4060972047
#  Activity_date     | Sep 14, 2020, 6:1...
#  Activity_name     | El siglo métrico
#  Activity_Type     | Ride
#  Elapsed_Time_Secs | 20592
#  Distance_KM       | 97.52
#  Elapsed_Time_1    | 20592.0
#  Moving_Time_Secs  | 16822.0
#  Distance_1        | 97523.8984375
#  Max_Speed         | 15.100000381469728
#  Average_Speed     | 5.797402381896973
#  Elevation_Gain    | 499.1468505859375
#  Elevation_Loss    | 499.1468505859375
#  Elevation_Low     | 180.3000030517578
#  Elevation_High    | 318.8999938964844
#  Max_Grade         | 12.699999809265137
#  Average_Grade     | 0.0
#  Average_Watts     | 129.0691680908203
#  Calories          | 2420.8896484375
# -RECORD 2---------------------------------
#  _c0               | 230
#  Activity_ID       | 4838696242
#  Activity_date     | Feb 23, 2021, 6:3...
#  Activity_name     | Lunch Ride
#  Activity_Type     | Ride
#  Elapsed_Time_Secs | 18190
#  Distance_KM       | 84.81
#  Elapsed_Time_1    | 18190.0
#  Moving_Time_Secs  | 13663.0
#  Distance_1        | 84817.5
#  Max_Speed         | 13.800000190734863
#  Average_Speed     | 6.207824230194092
#  Elevation_Gain    | 319.65789794921875
#  Elevation_Loss    | 319.5578918457031
#  Elevation_Low     | 144.1999969482422
#  Elevation_High    | 221.3000030517578
#  Max_Grade         | 17.899999618530273
#  Average_Grade     | 0.0001179001992568
#  Average_Watts     | 103.60050964355467
#  Calories          | 1578.2755126953125
# -RECORD 3---------------------------------
#  _c0               | 235
#  Activity_ID       | 4920464621
#  Activity_date     | Mar 9, 2021, 2:22...
#  Activity_name     | Morning Ride
#  Activity_Type     | Ride
#  Elapsed_Time_Secs | 23464
#  Distance_KM       | 119.4
#  Elapsed_Time_1    | 23464.0
#  Moving_Time_Secs  | 18432.0
#  Distance_1        | 119399.3984375
#  Max_Speed         | 16.5
#  Average_Speed     | 6.477831840515137
#  Elevation_Gain    | 580.8060913085938
#  Elevation_Loss    | 580.7060546875
#  Elevation_Low     | 168.0
#  Elevation_High    | 339.1000061035156
#  Max_Grade         | 16.0
#  Average_Grade     | 8.37525149108842e-05
#  Average_Watts     | 109.23184204101562
#  Calories          | 2244.89794921875
# -RECORD 4---------------------------------
#  _c0               | 254
#  Activity_ID       | 5121359409
#  Activity_date     | Apr 13, 2021, 10:...
#  Activity_name     | My first century
#  Activity_Type     | Ride
#  Elapsed_Time_Secs | 28995
#  Distance_KM       | 161.35
#  Elapsed_Time_1    | 28995.0
#  Moving_Time_Secs  | 24906.0
#  Distance_1        | 161350.90625
#  Max_Speed         | 12.399999618530272
#  Average_Speed     | 6.478394985198975
#  Elevation_Gain    | 630.592529296875
#  Elevation_Loss    | 630.592529296875
#  Elevation_Low     | 148.39999389648438
#  Elevation_High    | 339.1000061035156
#  Max_Grade         | 19.399999618530277
#  Average_Grade     | 0.0
#  Average_Watts     | 106.51892852783205
#  Calories          | 2958.05078125

# %%
df.filter(df.Distance_KM < 10).where(df.Activity_Type == 'Ride').show(5, vertical=True)
# Out:
# -RECORD 0---------------------------------
#  _c0               | 2
#  Activity_ID       | 797001969
#  Activity_date     | Dec 8, 2016, 4:28...
#  Activity_name     | Morning Ride
#  Activity_Type     | Ride
#  Elapsed_Time_Secs | 8
#  Distance_KM       | 0.03
#  Elapsed_Time_1    | 8.0
#  Moving_Time_Secs  | 8.0
#  Distance_1        | 30.600000381469727
#  Max_Speed         | 0.2000000029802322
#  Average_Speed     | null
#  Elevation_Gain    | 0.0
#  Elevation_Loss    | null
#  Elevation_Low     | 207.8999938964844
#  Elevation_High    | 207.8999938964844
#  Max_Grade         | 0.0
#  Average_Grade     | 0.0
#  Average_Watts     | 0.0
#  Calories          | null
# -RECORD 1---------------------------------
#  _c0               | 6
#  Activity_ID       | 874019573
#  Activity_date     | Feb 20, 2017, 10:...
#  Activity_name     | Afternoon Ride
#  Activity_Type     | Ride
#  Elapsed_Time_Secs | 8235
#  Distance_KM       | 9.82
#  Elapsed_Time_1    | 8235.0
#  Moving_Time_Secs  | 1646.0
#  Distance_1        | 9826.2001953125
#  Max_Speed         | 12.100000381469728
#  Average_Speed     | null
#  Elevation_Gain    | 59.80400466918945
#  Elevation_Loss    | null
#  Elevation_Low     | 208.0
#  Elevation_High    | 234.0
#  Max_Grade         | 11.0
#  Average_Grade     | -0.0010176873765885
#  Average_Watts     | 125.86026000976562
#  Calories          | null
# -RECORD 2---------------------------------
#  _c0               | 9
#  Activity_ID       | 900600691
#  Activity_date     | Mar 15, 2017, 12:...
#  Activity_name     | Evening Ride
#  Activity_Type     | Ride
#  Elapsed_Time_Secs | 2365
#  Distance_KM       | 5.49
#  Elapsed_Time_1    | 2365.0
#  Moving_Time_Secs  | 1912.0
#  Distance_1        | 5491.2001953125
#  Max_Speed         | 5.0
#  Average_Speed     | null
#  Elevation_Gain    | 15.713393211364746
#  Elevation_Loss    | null
#  Elevation_Low     | 210.0
#  Elevation_High    | 226.0
#  Max_Grade         | 5.699999809265137
#  Average_Grade     | -0.0291375294327735
#  Average_Watts     | 35.89242172241211
#  Calories          | null
# -RECORD 3---------------------------------
#  _c0               | 10
#  Activity_ID       | 912020485
#  Activity_date     | Mar 16, 2017, 12:...
#  Activity_name     | Evening Ride
#  Activity_Type     | Ride
#  Elapsed_Time_Secs | 1272
#  Distance_KM       | 3.69
#  Elapsed_Time_1    | 1272.0
#  Moving_Time_Secs  | 1241.0
#  Distance_1        | 3698.300048828125
#  Max_Speed         | 5.300000190734863
#  Average_Speed     | null
#  Elevation_Gain    | 0.0
#  Elevation_Loss    | null
#  Elevation_Low     | 217.1000061035156
#  Elevation_High    | 227.0
#  Max_Grade         | 5.5
#  Average_Grade     | 0.0081118354573845
#  Average_Watts     | 61.57212066650391
#  Calories          | 85.19823455810547
# -RECORD 4---------------------------------
#  _c0               | 18
#  Activity_ID       | 990524656
#  Activity_date     | May 16, 2017, 4:3...
#  Activity_name     | Lunch Ride
#  Activity_Type     | Ride
#  Elapsed_Time_Secs | 9479
#  Distance_KM       | 6.4
#  Elapsed_Time_1    | 9479.0
#  Moving_Time_Secs  | 1292.0
#  Distance_1        | 6401.5
#  Max_Speed         | 13.0
#  Average_Speed     | null
#  Elevation_Gain    | 0.0
#  Elevation_Loss    | null
#  Elevation_Low     | 193.8000030517578
#  Elevation_High    | 220.0
#  Max_Grade         | 6.699999809265137
#  Average_Grade     | -0.3561665117740631
#  Average_Watts     | 85.16653442382812
#  Calories          | null
# only showing top 5 rows

# %%
df.select(df.Distance_KM,when(df.Distance_KM > 80, 'Long Ride')
          .otherwise("Less Long")
          .alias('Ride_Length')
         ).where(df.Distance_KM > 50).show(20)
#I added a where statement to narrow the results a little and actually see 
# some long rides.
# There are fewer than 20 total in the filter
# Out:
# +-----------+-----------+
# |Distance_KM|Ride_Length|
# +-----------+-----------+
# |      56.76|  Less Long|
# |      76.13|  Less Long|
# |      52.48|  Less Long|
# |      82.52|  Long Ride|
# |      97.52|  Long Ride|
# |      84.81|  Long Ride|
# |      119.4|  Long Ride|
# |      57.08|  Less Long|
# |     161.35|  Long Ride|
# |      79.74|  Less Long|
# |      51.85|  Less Long|
# |      57.85|  Less Long|
# |      54.51|  Less Long|
# |      58.85|  Less Long|
# +-----------+-----------+

# %%
df.select(df.Distance_KM, 
         (when(df.Distance_KM<10,'very short')
         .when(df.Distance_KM<25,'short')
         .when(df.Distance_KM<50,'medium')
         .when(df.Distance_KM<80,'long')
         .otherwise('very long')
         .alias('Ride_Length'))
         ).where(df.Activity_Type=='Ride').show(50)
# Out:
# +-----------+-----------+
# |Distance_KM|Ride_Length|
# +-----------+-----------+
# |      13.48|      short|
# |      23.61|      short|
# |       0.03| very short|
# |      10.22|      short|
# |      26.16|     medium|
# |      12.25|      short|
# |       9.82| very short|
# |      37.42|     medium|
# |      47.55|     medium|
# |       5.49| very short|
# |       3.69| very short|
# |      28.42|     medium|
# |      18.62|      short|
# |      33.63|     medium|
# |      16.09|      short|
# |      48.86|     medium|
# |      16.74|      short|
# |      46.25|     medium|
# |        6.4| very short|
# |      18.31|      short|
# |      50.69|       long|
# |      56.76|       long|
# |      35.21|     medium|
# |      32.32|     medium|
# |      11.97|      short|
# |      37.74|     medium|
# |      76.13|       long|
# |       36.8|     medium|
# |       5.07| very short|
# |      30.49|     medium|
# |      46.69|     medium|
# |      24.74|      short|
# |       5.41| very short|
# |      35.51|     medium|
# |      11.34|      short|
# |      17.63|      short|
# |      30.32|     medium|
# |      21.96|      short|
# |      15.05|      short|
# |      45.09|     medium|
# |       20.2|      short|
# |      31.41|     medium|
# |        9.4| very short|
# |       5.46| very short|
# |       6.47| very short|
# |      20.18|      short|
# |       4.49| very short|
# |       8.15| very short|
# |       6.27| very short|
# |       6.99| very short|
# +-----------+-----------+
# only showing top 50 rows

# %%
df.columns
# Out:
# ['_c0',
#  'Activity_ID',
#  'Activity_date',
#  'Activity_name',
#  'Activity_Type',
#  'Elapsed_Time_Secs',
#  'Distance_KM',
#  'Elapsed_Time_1',
#  'Moving_Time_Secs',
#  'Distance_1',
#  'Max_Speed',
#  'Average_Speed',
#  'Elevation_Gain',
#  'Elevation_Loss',
#  'Elevation_Low',
#  'Elevation_High',
#  'Max_Grade',
#  'Average_Grade',
#  'Average_Watts',
#  'Calories']

# %%
df.select(df.Distance_KM, df.Elapsed_Time_Secs).withColumn("Avg_Speed_KM_per_Hr", \
                    col('Distance_KM') / (col('Elapsed_Time_Secs')/3600)).show()
# Out:
# +-----------+-----------------+-------------------+
# |Distance_KM|Elapsed_Time_Secs|Avg_Speed_KM_per_Hr|
# +-----------+-----------------+-------------------+
# |      13.48|             2352|  20.63265306122449|
# |      23.61|             5495| 15.467879890809828|
# |       0.03|                8|               13.5|
# |      10.22|             7942|  4.632586250314783|
# |      26.16|             4983|   18.8994581577363|
# |      12.25|            11270| 3.9130434782608696|
# |       9.82|             8235|  4.292896174863388|
# |      37.42|             9322| 14.450976185367946|
# |      47.55|            14725| 11.625127334465194|
# |       5.49|             2365|  8.356871035940804|
# |       3.69|             1272| 10.443396226415095|
# |      28.42|             6665| 15.350637659414854|
# |      18.62|           267771|0.25033330719159286|
# |      33.63|            17863|  6.777584952135699|
# |      16.09|            15660|  3.698850574712644|
# |      48.86|            15832| 11.110156644770086|
# |      16.74|           720241| 0.0836719931245236|
# |      46.25|            10302| 16.161910308677925|
# |        6.4|             9479| 2.4306361430530647|
# |       6.19|             2185| 10.198627002288331|
# +-----------+-----------------+-------------------+
# only showing top 20 rows

# %%
df.select(df.Distance_KM, df.Elapsed_Time_Secs).withColumn("Avg_Speed_KM_per_Hr", \
col('Distance_KM') / (col('Elapsed_Time_Secs')/3600)).sort(desc('Avg_Speed_KM_per_Hr'))\
.show()
# Out:
# +-----------+-----------------+-------------------+
# |Distance_KM|Elapsed_Time_Secs|Avg_Speed_KM_per_Hr|
# +-----------+-----------------+-------------------+
# |      46.26|             5975| 27.872133891213387|
# |      40.51|             5333|  27.34595912244515|
# |      39.02|             5182| 27.107680432265536|
# |      44.31|             6179| 25.815827803851757|
# |      25.47|             3630| 25.259504132231406|
# |      38.49|             5555| 24.944014401440143|
# |      23.69|             3464|  24.62009237875289|
# |      26.28|             3873| 24.427575522850503|
# |      28.78|             4252|  24.36688617121355|
# |       6.27|              934| 24.167023554603855|
# |      26.02|             3892| 24.067831449126412|
# |      28.62|             4285|  24.04480746791132|
# |      32.41|             4878|  23.91881918819188|
# |       7.32|             1104| 23.869565217391308|
# |       38.9|             5914| 23.679404802164356|
# |      39.35|             5985| 23.669172932330827|
# |      25.88|             3938| 23.658710005078717|
# |      21.17|             3228|   23.6096654275093|
# |      30.99|             4756| 23.457527333894028|
# |      26.45|             4069| 23.401327107397396|
# +-----------+-----------------+-------------------+
# only showing top 20 rows

# %% [markdown]
# - Great use of sort()

# %%
df.select(
    df.Distance_KM, 
         (
             when(df.Distance_KM<10,'very short')
         .when(df.Distance_KM<25,'short')
         .when(df.Distance_KM<50,'medium')
         .when(df.Distance_KM<80,'long')
         .otherwise('very long')
         .alias('Ride_Length')
         )
    ,df.Elapsed_Time_Secs)\
    .withColumn("Avg_Speed_KM_per_Hr",
                col('Distance_KM') / (col('Elapsed_Time_Secs')/3600))\
    .sort(asc('Ride_Length'))\
    .sort(desc('Avg_Speed_KM_per_Hr'))\
    .where(df.Activity_Type=='Ride').show(20)
# Out:
# +-----------+-----------+-----------------+-------------------+
# |Distance_KM|Ride_Length|Elapsed_Time_Secs|Avg_Speed_KM_per_Hr|
# +-----------+-----------+-----------------+-------------------+
# |      46.26|     medium|             5975| 27.872133891213387|
# |      40.51|     medium|             5333|  27.34595912244515|
# |      39.02|     medium|             5182| 27.107680432265536|
# |      44.31|     medium|             6179| 25.815827803851757|
# |      25.47|     medium|             3630| 25.259504132231406|
# |      38.49|     medium|             5555| 24.944014401440143|
# |      23.69|      short|             3464|  24.62009237875289|
# |      26.28|     medium|             3873| 24.427575522850503|
# |      28.78|     medium|             4252|  24.36688617121355|
# |       6.27| very short|              934| 24.167023554603855|
# |      26.02|     medium|             3892| 24.067831449126412|
# |      28.62|     medium|             4285|  24.04480746791132|
# |      32.41|     medium|             4878|  23.91881918819188|
# |       7.32| very short|             1104| 23.869565217391308|
# |       38.9|     medium|             5914| 23.679404802164356|
# |      39.35|     medium|             5985| 23.669172932330827|
# |      25.88|     medium|             3938| 23.658710005078717|
# |      21.17|      short|             3228|   23.6096654275093|
# |      30.99|     medium|             4756| 23.457527333894028|
# |      26.45|     medium|             4069| 23.401327107397396|
# +-----------+-----------+-----------------+-------------------+
# only showing top 20 rows

# %% [markdown]
# - not sure it's possible to groupBy then sort
# - maybe by using .agg()?

# %%
df.select(
    df.Distance_KM, 
         (
             when(df.Distance_KM<10,'very short')
         .when(df.Distance_KM<25,'short')
         .when(df.Distance_KM<50,'medium')
         .when(df.Distance_KM<80,'long')
         .otherwise('very long')
         .alias('Ride_Length')
         )
    ,df.Elapsed_Time_Secs)\
    .withColumn("Avg_Speed_KM_per_Hr",
                col('Distance_KM') / (col('Elapsed_Time_Secs')/3600))\
    .orderBy('Ride_Length',desc('Avg_Speed_KM_per_Hr'))\
    .where(col('Ride_Length')=='very long').show()
# Out:
# +-----------+-----------+-----------------+-------------------+
# |Distance_KM|Ride_Length|Elapsed_Time_Secs|Avg_Speed_KM_per_Hr|
# +-----------+-----------+-----------------+-------------------+
# |     161.35|  very long|            28995| 20.033109156751163|
# |      119.4|  very long|            23464| 18.319127173542448|
# |      82.52|  very long|            16873|   17.6063533455817|
# |      97.52|  very long|            20592|  17.04895104895105|
# |      84.81|  very long|            18190| 16.784826827927432|
# +-----------+-----------+-----------------+-------------------+

# %% [markdown]
# ## Finally got it--remember to define the two arguments in the orderBy()

# %%
df.select(
    df.Distance_KM, 
         (
             when(df.Distance_KM<10,'very short')
         .when(df.Distance_KM<25,'short')
         .when(df.Distance_KM<50,'medium')
         .when(df.Distance_KM<80,'long')
         .otherwise('very long')
         .alias('Ride_Length')
         )
    ,df.Elapsed_Time_Secs)\
    .withColumn("Avg_Speed_KM_per_Hr",
                col('Distance_KM') / (col('Elapsed_Time_Secs')/3600))\
    .rollup('Ride_Length').count().sort('Ride_Length').show()
# Out:
# +-----------+-----+
# |Ride_Length|count|
# +-----------+-----+
# |       null|  521|
# |       long|   12|
# |     medium|  122|
# |      short|   89|
# |  very long|    5|
# | very short|  293|
# +-----------+-----+

# %% [markdown]
# ## `rollup` showing the count of ride lengths...where are the nulls coming from?
# ## oh, that's an aspect of .rollup() duh

# %%
df.select(
    df.Distance_KM, 
         (
             when(df.Distance_KM<10,'very short')
         .when(df.Distance_KM<25,'short')
         .when(df.Distance_KM<50,'medium')
         .when(df.Distance_KM<80,'long')
         .otherwise('very long')
         .alias('Ride_Length')
         )
    ,df.Elapsed_Time_Secs)\
    .withColumn("Avg_Speed_KM_per_Hr",
                col('Distance_KM') / (col('Elapsed_Time_Secs')/3600))\
             ,(
             when(col('Avg_Speed_KM_per_Hr')<10,'slow')
         .when(col('Avg_Speed_KM_per_Hr')<15,'medium')
         .otherwise('fast')
         .alias('Ride_Speed')
         ).where(df.Activity_Type=='Ride').show(20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-89-52d8cf6de704> in <module>
#      12     .withColumn("Avg_Speed_KM_per_Hr",
#      13                 col('Distance_KM') / (col('Elapsed_Time_Secs')/3600))\
# ---> 14              ,(
#      15              when(col('Avg_Speed_KM_per_Hr')<10,'slow')
#      16          .when(col('Avg_Speed_KM_per_Hr')<15,'medium')
#
# TypeError: 'Column' object is not callable
